# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import time
from transformers import AutoTokenizer, AutoModel
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Load dataset
dataset_path = "/kaggle/input/diseases-and-symptoms-dataset/Final_Augmented_dataset_Diseases_and_Symptoms.csv"
df = pd.read_csv(dataset_path)

# Encode labels
label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['diseases'])

# Convert symptom columns to description
df['text_description'] = df.drop(columns=['diseases', 'label']).apply(lambda row: ' '.join(row.index[row == 1]), axis=1)

# Split data
X_train, X_test, y_train, y_test = train_test_split(df['text_description'], df['label'], test_size=0.2, random_state=42)

# Load tokenizers
xlmr_tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-base")
ernie_tokenizer = AutoTokenizer.from_pretrained("nghuyong/ernie-2.0-base-en")

# Dataset class
class SymptomHybridDataset(Dataset):
    def __init__(self, texts, labels, xlmr_tokenizer, ernie_tokenizer, max_length=128):
        self.texts = texts.tolist()
        self.labels = labels.tolist()
        self.xlmr_tokenizer = xlmr_tokenizer
        self.ernie_tokenizer = ernie_tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        xlmr_encoding = self.xlmr_tokenizer(
            self.texts[idx], truncation=True, padding="max_length",
            max_length=self.max_length, return_tensors="pt"
        )
        ernie_encoding = self.ernie_tokenizer(
            self.texts[idx], truncation=True, padding="max_length",
            max_length=self.max_length, return_tensors="pt"
        )
        return {
            "xlmr": {k: v.squeeze(0) for k, v in xlmr_encoding.items()},
            "ernie": {k: v.squeeze(0) for k, v in ernie_encoding.items()},
            "label": torch.tensor(self.labels[idx])
        }

# Data loaders
train_dataset = SymptomHybridDataset(X_train, y_train, xlmr_tokenizer, ernie_tokenizer)
test_dataset = SymptomHybridDataset(X_test, y_test, xlmr_tokenizer, ernie_tokenizer)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# Hybrid model
class XLMR_ERNIE_Classifier(nn.Module):
    def __init__(self, num_labels):
        super(XLMR_ERNIE_Classifier, self).__init__()
        self.xlmr = AutoModel.from_pretrained("xlm-roberta-base")
        self.ernie = AutoModel.from_pretrained("nghuyong/ernie-2.0-base-en")
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Linear(768 * 2, num_labels)

    def forward(self, xlmr_inputs, ernie_inputs):
        xlmr_output = self.xlmr(**xlmr_inputs).last_hidden_state[:, 0, :]
        ernie_output = self.ernie(**ernie_inputs).last_hidden_state[:, 0, :]
        combined = torch.cat((xlmr_output, ernie_output), dim=1)
        out = self.dropout(combined)
        return self.classifier(out)

# Initialize model
model = XLMR_ERNIE_Classifier(num_labels=len(label_encoder.classes_)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=2e-5)

# Training loop
num_epochs = 3
train_loss_values, test_loss_values = [], []
train_accuracies, test_accuracies = [], []
start_time = time.time()

for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0
    correct_train, total_train = 0, 0

    for batch in train_loader:
        optimizer.zero_grad()
        xlmr_inputs = {k: v.to(device) for k, v in batch["xlmr"].items()}
        ernie_inputs = {k: v.to(device) for k, v in batch["ernie"].items()}
        labels = batch["label"].to(device)

        outputs = model(xlmr_inputs, ernie_inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()
        predictions = torch.argmax(outputs, dim=1)
        correct_train += (predictions == labels).sum().item()
        total_train += labels.size(0)

    avg_train_loss = total_train_loss / len(train_loader)
    train_accuracy = correct_train / total_train

    model.eval()
    total_test_loss = 0
    correct_test, total_test = 0, 0

    with torch.no_grad():
        for batch in test_loader:
            xlmr_inputs = {k: v.to(device) for k, v in batch["xlmr"].items()}
            ernie_inputs = {k: v.to(device) for k, v in batch["ernie"].items()}
            labels = batch["label"].to(device)

            outputs = model(xlmr_inputs, ernie_inputs)
            loss = criterion(outputs, labels)

            total_test_loss += loss.item()
            predictions = torch.argmax(outputs, dim=1)
            correct_test += (predictions == labels).sum().item()
            total_test += labels.size(0)

    avg_test_loss = total_test_loss / len(test_loader)
    test_accuracy = correct_test / total_test

    train_loss_values.append(avg_train_loss)
    test_loss_values.append(avg_test_loss)
    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch+1}: Train Loss = {avg_train_loss:.4f}, Train Acc = {train_accuracy:.4f}, Test Loss = {avg_test_loss:.4f}, Test Acc = {test_accuracy:.4f}")

end_time = time.time()
print(f"\nTotal Training Time: {end_time - start_time:.2f} seconds")
# Out:
# Using device: cuda
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/464 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Epoch 1: Train Loss = 1.2359, Train Acc = 0.7313, Test Loss = 0.5041, Test Acc = 0.8363
# Epoch 2: Train Loss = 0.4936, Train Acc = 0.8411, Test Loss = 0.4484, Test Acc = 0.8465
# Epoch 3: Train Loss = 0.4328, Train Acc = 0.8502, Test Loss = 0.4249, Test Acc = 0.8469
#
# Total Training Time: 32257.08 seconds

# %%
# Plotting
plt.plot(range(1, num_epochs+1), train_loss_values, marker='o', label='Train Loss')
plt.plot(range(1, num_epochs+1), test_loss_values, marker='s', label='Test Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Curve")
plt.show()

plt.plot(range(1, num_epochs+1), train_accuracies, marker='o', label='Train Acc')
plt.plot(range(1, num_epochs+1), test_accuracies, marker='s', label='Test Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Curve")
plt.show()

# Final evaluation
y_true, y_pred = [], []
model.eval()
with torch.no_grad():
    for batch in test_loader:
        xlmr_inputs = {k: v.to(device) for k, v in batch["xlmr"].items()}
        ernie_inputs = {k: v.to(device) for k, v in batch["ernie"].items()}
        labels = batch["label"].to(device)

        outputs = model(xlmr_inputs, ernie_inputs)
        predictions = torch.argmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predictions.cpu().numpy())

print("\nClassification Report:")
print(classification_report(y_true, y_pred, labels=np.arange(len(label_encoder.classes_)), target_names=label_encoder.classes_))
# Out:
# Classification Report:
#                                                           precision    recall  f1-score   support
#
#                                abdominal aortic aneurysm       0.91      1.00      0.95        20
#                                         abdominal hernia       0.94      0.89      0.91        81
#                                          abscess of nose       0.85      0.86      0.85        58
#                                      abscess of the lung       1.00      0.83      0.91         6
#                                   abscess of the pharynx       0.93      0.87      0.90        63
#                                     acanthosis nigricans       0.75      0.50      0.60         6
#                                                acariasis       1.00      0.80      0.89         5
#                                                achalasia       0.73      0.80      0.76        20
#                                                     acne       0.93      0.72      0.81       103
#                                        actinic keratosis       0.86      0.78      0.82       179
#                                      acute bronchiolitis       0.98      0.90      0.94       253
#                                         acute bronchitis       0.81      0.67      0.74       221
#                                       acute bronchospasm       0.71      0.72      0.71       187
#                    acute fatty liver of pregnancy (aflp)       0.50      1.00      0.67         3
#                                           acute glaucoma       0.23      0.87      0.36        31
#                                      acute kidney injury       0.95      0.95      0.95       209
#                                       acute otitis media       0.68      0.85      0.75       145
#                                       acute pancreatitis       0.98      0.84      0.90       246
#               acute respiratory distress syndrome (ards)       0.95      0.85      0.90        82
#                                          acute sinusitis       0.77      0.88      0.82       179
#                                    acute stress reaction       0.93      0.90      0.91       185
#                      adhesive capsulitis of the shoulder       1.00      0.71      0.83        17
#                                      adjustment reaction       0.65      0.81      0.72        89
#                                          adrenal adenoma       1.00      0.89      0.94         9
#                                           adrenal cancer       0.00      0.00      0.00         1
#                                            alcohol abuse       0.86      0.86      0.86        87
#                                     alcohol intoxication       0.92      0.97      0.94        62
#                                       alcohol withdrawal       0.99      0.89      0.94       148
#                                  alcoholic liver disease       0.95      0.91      0.93        44
#                                                  allergy       0.95      0.89      0.92       182
#                                       allergy to animals       1.00      1.00      1.00         8
#                                                 alopecia       0.73      0.94      0.83        70
#                                        alzheimer disease       0.96      0.94      0.95        70
#                                                amblyopia       0.87      1.00      0.93        13
#                                              amyloidosis       0.00      0.00      0.00         1
#                      amyotrophic lateral sclerosis (als)       1.00      0.89      0.94         9
#                                             anal fissure       0.92      0.94      0.93        36
#                                             anal fistula       1.00      1.00      1.00         1
#                                                   anemia       0.96      0.93      0.95        57
#                     anemia due to chronic kidney disease       1.00      0.67      0.80         6
#                                 anemia due to malignancy       1.00      1.00      1.00         1
#                                anemia of chronic disease       1.00      0.86      0.92         7
#                                                   angina       0.96      0.88      0.92       179
#                                   ankylosing spondylitis       0.87      0.89      0.88       126
#                                                  anxiety       1.00      0.91      0.95       236
#                                     aortic valve disease       0.79      0.99      0.88        84
#                                                  aphakia       0.00      0.00      0.00         1
#                                           aphthous ulcer       0.85      0.91      0.88        44
#                                          aplastic anemia       1.00      1.00      1.00        16
#                                             appendicitis       0.80      0.89      0.84       183
#                                               arrhythmia       1.00      0.60      0.75        52
#                                     arthritis of the hip       0.91      0.97      0.94       228
#                                    ascending cholangitis       1.00      0.90      0.95        10
#                                        asperger syndrome       0.85      0.85      0.85        80
#                                            aspergillosis       1.00      1.00      1.00         3
#                                                   asthma       0.83      0.65      0.73       189
#                                              astigmatism       0.79      0.62      0.69        55
#                                              atelectasis       1.00      0.41      0.58        22
#                                           athlete's foot       0.71      0.68      0.70        73
#                                           atonic bladder       1.00      0.73      0.85        15
#                                      atrial fibrillation       0.62      0.42      0.50        19
#                                           atrial flutter       1.00      0.88      0.94        51
#                                  atrophic skin condition       0.74      0.84      0.78        85
#                                       atrophic vaginitis       0.88      0.86      0.87        66
#                         atrophy of the corpus cavernosum       1.00      0.40      0.57         5
#          attention deficit hyperactivity disorder (adhd)       0.78      0.86      0.82        99
#                                                   autism       0.89      0.97      0.93        73
#                        autonomic nervous system disorder       0.91      0.95      0.93        21
#                                       avascular necrosis       0.00      0.00      0.00         8
#                                                balanitis       1.00      0.97      0.99       106
#                                               bell palsy       0.92      0.96      0.94       140
#                                       benign kidney cyst       0.93      0.88      0.90        48
#             benign paroxysmal positional vertical (bppv)       0.93      0.98      0.95        82
#                       benign prostatic hyperplasia (bph)       0.96      0.93      0.95       244
#                    benign vaginal discharge (leukorrhea)       0.95      0.85      0.90       131
#                                         bipolar disorder       0.67      0.67      0.67       132
#                                             birth trauma       1.00      1.00      1.00         1
#                                           bladder cancer       1.00      0.96      0.98        27
#                                         bladder disorder       0.43      0.89      0.58        83
#                                      bladder obstruction       0.98      0.91      0.94        66
#                                              blepharitis       0.73      0.74      0.74       180
#                                            blepharospasm       1.00      1.00      1.00         1
#                                              bone cancer       1.00      0.70      0.82        23
#                                            bone disorder       1.00      1.00      1.00        51
#                              bone spur of the calcaneous       0.56      1.00      0.71         5
#                                        brachial neuritis       0.89      0.92      0.90       177
#                                             brain cancer       0.82      0.91      0.86        45
#                                            breast cancer       0.00      0.00      0.00         0
#                                              breast cyst       0.75      0.60      0.67         5
#                              breast infection (mastitis)       0.97      1.00      0.98        96
#                                             broken tooth       0.97      0.91      0.94        33
#                                                   bunion       0.90      1.00      0.95         9
#                                                     burn       0.90      0.90      0.90        10
#                                                 bursitis       0.99      0.98      0.98       252
#                                                   callus       0.82      0.77      0.80        97
#                                carbon monoxide poisoning       0.67      0.84      0.74        19
#                                       carcinoid syndrome       0.00      0.00      0.00         2
#                                           cardiac arrest       0.88      0.94      0.91        72
#                                           cardiomyopathy       0.81      0.83      0.82        52
#                                   carpal tunnel syndrome       0.92      0.95      0.94       167
#                                      cat scratch disease       0.00      0.00      0.00         2
#                                                 cataract       0.83      0.61      0.70       115
#                                           celiac disease       0.65      0.90      0.75        29
#                           cellulitis or abscess of mouth       1.00      0.94      0.97        33
#                                  central atherosclerosis       0.50      0.75      0.60         4
#                 central retinal artery or vein occlusion       1.00      0.71      0.83        14
#                                           cerebral edema       0.87      0.95      0.91        21
#                                           cerebral palsy       0.90      0.86      0.88        21
#                                          cervical cancer       1.00      0.95      0.98        21
#                                        cervical disorder       0.88      0.78      0.82         9
#                                               cervicitis       0.81      0.83      0.82        76
#                                                chalazion       0.79      0.96      0.86       112
#                                               chickenpox       1.00      0.83      0.90        23
#                                                chlamydia       0.70      0.53      0.60        30
#                                            cholecystitis       0.94      0.74      0.83       275
#                                      choledocholithiasis       0.97      0.84      0.90        85
#                                            cholesteatoma       0.86      0.86      0.86         7
#                            chondromalacia of the patella       0.62      0.83      0.71         6
#                                          chorioretinitis       1.00      0.87      0.93        15
#                                        chronic back pain       0.98      0.91      0.94       187
#                                     chronic constipation       0.75      0.88      0.81       178
#                                         chronic glaucoma       0.73      0.73      0.73       146
# chronic inflammatory demyelinating polyneuropathy (cidp)       0.50      0.50      0.50         2
#                                   chronic kidney disease       1.00      1.00      1.00         2
#                                        chronic knee pain       0.86      0.58      0.69        33
#             chronic obstructive pulmonary disease (copd)       0.62      0.72      0.67       168
#                                     chronic otitis media       0.97      0.82      0.88       136
#                                    chronic pain disorder       0.83      0.80      0.82       127
#                                     chronic pancreatitis       0.98      0.98      0.98        55
#                                  chronic rheumatic fever       0.59      0.94      0.73        35
#                                        chronic sinusitis       0.79      0.90      0.84       137
#                                            chronic ulcer       0.00      0.00      0.00         0
#                                                cirrhosis       0.81      0.98      0.89        56
#                          coagulation (bleeding) disorder       0.89      1.00      0.94        16
#                                                cold sore       1.00      0.86      0.93        36
#                                            colonic polyp       0.85      0.93      0.89        60
#                                        colorectal cancer       0.20      0.50      0.29         2
#                                              common cold       0.80      0.90      0.84       148
#                           complex regional pain syndrome       0.91      0.86      0.88       244
#                                               concussion       1.00      0.96      0.98       239
#                                         conduct disorder       0.98      0.83      0.90       134
#                                  conductive hearing loss       0.85      0.90      0.88       103
#                                  congenital heart defect       1.00      1.00      1.00         8
#                         congenital malformation syndrome       1.00      1.00      1.00         2
#                                           conjunctivitis       0.98      0.86      0.92       197
#                            conjunctivitis due to allergy       0.96      0.85      0.90       242
#                           conjunctivitis due to bacteria       0.88      0.91      0.89        32
#                              conjunctivitis due to virus       0.75      0.86      0.80       131
#                               connective tissue disorder       0.00      0.00      0.00         0
#                                       contact dermatitis       0.99      0.71      0.83       192
#                                      conversion disorder       1.00      1.00      1.00         2
#                                         cornea infection       0.98      0.70      0.82       186
#                                         corneal abrasion       0.42      0.88      0.57       104
#                                         corneal disorder       0.43      0.58      0.49       122
#                                 coronary atherosclerosis       0.77      0.77      0.77        22
#                                      cranial nerve palsy       0.93      0.94      0.93        67
#                                            crohn disease       0.71      0.85      0.78        75
#                                                    croup       0.82      0.83      0.83       202
#                                          crushing injury       0.77      0.91      0.83        11
#                                           cryptococcosis       1.00      1.00      1.00         5
#                                           cryptorchidism       0.00      0.00      0.00         0
#                                         cushing syndrome       1.00      1.00      1.00         2
#                                       cyst of the eyelid       1.00      1.00      1.00         4
#                                          cystic fibrosis       1.00      1.00      1.00         4
#                                            cysticercosis       0.70      0.78      0.74         9
#                                                 cystitis       0.77      0.77      0.77       266
#                                      de quervain disease       1.00      0.92      0.96        12
#                                          decubitus ulcer       0.00      0.00      0.00         0
#                               deep vein thrombosis (dvt)       0.92      0.90      0.91        40
#                                degenerative disc disease       0.53      0.92      0.67       182
#                                                 delirium       0.87      0.92      0.89       136
#                                                 dementia       0.94      0.72      0.82        69
#                                             dengue fever       0.00      0.00      0.00         1
#                                            dental caries       0.94      0.91      0.92       236
#                                               depression       0.70      0.73      0.71       198
#                           dermatitis due to sun exposure       1.00      0.75      0.86        88
#                                 developmental disability       0.97      0.93      0.95       188
#                                    deviated nasal septum       0.93      0.94      0.94       126
#                                                 diabetes       0.00      0.00      0.00         1
#                                       diabetes insipidus       0.00      0.00      0.00         0
#                                    diabetic ketoacidosis       0.97      0.89      0.93       119
#                                  diabetic kidney disease       0.00      0.00      0.00         0
#                           diabetic peripheral neuropathy       0.89      0.95      0.92        83
#                                     diabetic retinopathy       0.53      0.76      0.62        88
#                                              diaper rash       0.93      0.99      0.96       200
#                                 dislocation of the ankle       0.80      1.00      0.89         4
#                                 dislocation of the elbow       1.00      0.74      0.85        19
#                                dislocation of the finger       1.00      1.00      1.00         3
#                                  dislocation of the foot       1.00      1.00      1.00         3
#                                   dislocation of the hip       0.00      0.00      0.00         4
#                                  dislocation of the knee       0.00      0.00      0.00         0
#                               dislocation of the patella       0.00      0.00      0.00         0
#                              dislocation of the shoulder       1.00      0.78      0.88         9
#                              dislocation of the vertebra       1.00      0.85      0.92        13
#                                 dislocation of the wrist       0.89      1.00      0.94         8
#                                    dissociative disorder       0.89      1.00      0.94        24
#                                           diverticulitis       0.82      0.81      0.82       246
#                                           diverticulosis       0.85      0.87      0.86       143
#                                            down syndrome       1.00      0.82      0.90        39
#                                               drug abuse       0.93      0.88      0.90       124
#                                drug abuse (barbiturates)       0.86      0.40      0.55        15
#                                     drug abuse (cocaine)       0.64      0.47      0.55        57
#                             drug abuse (methamphetamine)       0.97      0.85      0.91        74
#                                     drug abuse (opioids)       0.87      0.74      0.80       114
#                         drug poisoning due to medication       1.00      0.93      0.96        43
#                                            drug reaction       0.96      0.97      0.96       176
#                                          drug withdrawal       0.89      0.94      0.92        53
#                                 dry eye of unknown cause       1.00      0.40      0.57       174
#                                         dumping syndrome       0.00      0.00      0.00         0
#                                              dyshidrosis       1.00      0.94      0.97        17
#                                       dysthymic disorder       0.87      0.90      0.88        97
#                                          ear drum damage       0.83      0.92      0.87       192
#                                        ear wax impaction       0.80      0.80      0.80       133
#                                          eating disorder       0.99      0.98      0.98        83
#                                        ectopic pregnancy       0.75      0.65      0.69        65
#                                                ectropion       0.00      0.00      0.00         8
#                                                   eczema       0.86      0.74      0.79       227
#                                          edward syndrome       1.00      1.00      1.00         1
#                                                emphysema       0.70      0.88      0.78         8
#                                                  empyema       0.00      0.00      0.00         2
#                                             encephalitis       0.87      1.00      0.93        20
#                                             endocarditis       0.38      0.26      0.31        19
#                                       endometrial cancer       0.92      1.00      0.96        22
#                                  endometrial hyperplasia       1.00      1.00      1.00         8
#                                            endometriosis       0.91      0.95      0.93        64
#                                          endophthalmitis       0.71      1.00      0.83        10
#                  envenomation from spider or animal bite       0.95      0.98      0.96       106
#                                               ependymoma       1.00      0.75      0.86         4
#                                             epididymitis       0.94      0.98      0.96        95
#                                      epidural hemorrhage       0.00      0.00      0.00         0
#                                                 epilepsy       0.93      1.00      0.96        13
#                                     erectile dysfunction       0.91      0.84      0.88       126
#                                      erythema multiforme       0.88      0.78      0.82         9
#                                        esophageal cancer       0.81      0.89      0.85        19
#                                       esophageal varices       0.00      0.00      0.00         3
#                                              esophagitis       0.95      0.89      0.92       263
#                                         essential tremor       0.97      0.86      0.91        35
#               eustachian tube dysfunction (ear disorder)       0.99      0.89      0.93       169
#                           extrapyramidal effect of drugs       1.00      1.00      1.00        12
#                                   eye alignment disorder       0.99      0.97      0.98        88
#                                      factitious disorder       1.00      1.00      1.00         1
#                               female genitalia infection       1.00      1.00      1.00        36
#                      female infertility of unknown cause       1.00      1.00      1.00         6
#                                   fetal alcohol syndrome       0.00      0.00      0.00         0
#                                             fibroadenoma       1.00      0.92      0.96        24
#                               fibrocystic breast disease       1.00      1.00      1.00         2
#                                             fibromyalgia       0.78      0.72      0.75       127
#                                                flat feet       0.88      1.00      0.93         7
#                                                 floaters       0.00      0.00      0.00         6
#                                                      flu       0.93      0.83      0.88       116
#                                           fluid overload       0.95      0.87      0.91        69
#                                        folate deficiency       1.00      0.43      0.60         7
#                                             food allergy       0.80      0.99      0.88        95
#                                  foreign body in the ear       1.00      0.67      0.80         6
#                                  foreign body in the eye       0.56      0.75      0.64        57
#               foreign body in the gastrointestinal tract       1.00      1.00      1.00        22
#                                 foreign body in the nose       0.00      0.00      0.00         0
#                               foreign body in the throat       0.97      0.94      0.96        35
#                               foreign body in the vagina       1.00      0.75      0.86         4
#                                    fracture of the ankle       0.83      0.45      0.59        11
#                                      fracture of the arm       0.85      0.90      0.87        81
#                             fracture of the facial bones       0.97      0.91      0.94        96
#                                   fracture of the finger       0.00      0.00      0.00         1
#                                     fracture of the foot       0.00      0.00      0.00         3
#                                     fracture of the hand       0.73      0.73      0.73        22
#                                      fracture of the jaw       1.00      0.83      0.91        12
#                                      fracture of the leg       0.89      0.95      0.92       148
#                                     fracture of the neck       0.60      0.90      0.72        10
#                                  fracture of the patella       0.95      1.00      0.98        20
#                                   fracture of the pelvis       0.83      0.79      0.81        43
#                                      fracture of the rib       0.93      0.96      0.95       172
#                                 fracture of the shoulder       0.92      1.00      0.96        35
#                                    fracture of the skull       1.00      1.00      1.00         9
#                                 fracture of the vertebra       1.00      0.94      0.97        50
#                                         friedrich ataxia       0.00      0.00      0.00         0
#                                                frostbite       1.00      0.75      0.86         4
#                             fungal infection of the hair       0.62      0.78      0.69       279
#                             fungal infection of the skin       0.64      0.75      0.69       126
#                                   g6pd enzyme deficiency       0.00      0.00      0.00         1
#                            galactorrhea of unknown cause       1.00      0.67      0.80         3
#                                                gallstone       0.65      0.95      0.77       176
#                                            ganglion cyst       0.98      0.97      0.97       158
#                                             gas gangrene       0.00      0.00      0.00         0
#                                                gastritis       0.97      0.73      0.83       141
#                                     gastroduodenal ulcer       0.96      0.79      0.87       139
#                   gastroesophageal reflux disease (gerd)       0.85      0.97      0.91        76
#                              gastrointestinal hemorrhage       0.80      0.96      0.87       239
#                                            gastroparesis       0.83      0.65      0.73        37
#                                           genital herpes       1.00      0.91      0.95        45
#                                     gestational diabetes       0.57      0.67      0.62         6
#                                                 glaucoma       0.71      0.68      0.69        96
#                                glucocorticoid deficiency       1.00      1.00      1.00         2
#                                                   goiter       0.89      1.00      0.94        17
#                                                gonorrhea       1.00      1.00      1.00        17
#                                                     gout       0.94      0.92      0.93       252
#                                      granuloma inguinale       0.50      0.50      0.50         2
#                                           graves disease       0.93      0.88      0.91        49
#                                  guillain barre syndrome       1.00      1.00      1.00        17
#                                              gum disease       0.83      0.85      0.84       197
#                                             gynecomastia       0.94      0.94      0.94        18
#                                               hammer toe       0.00      0.00      0.00         0
#                                    hashimoto thyroiditis       0.00      0.00      0.00         1
#                                     head and neck cancer       0.92      0.97      0.95        75
#                                              head injury       0.87      0.92      0.89        36
#                           headache after lumbar puncture       0.94      0.97      0.95        30
#                                             heart attack       0.92      0.95      0.94       167
#                                              heart block       0.75      0.89      0.81       110
#                                          heart contusion       1.00      1.00      1.00         3
#                                            heart failure       0.96      0.91      0.93       176
#                                          heat exhaustion       0.84      0.79      0.81        47
#                                              heat stroke       0.00      0.00      0.00         0
#                                               hemangioma       0.85      0.78      0.82       130
#                                             hemarthrosis       1.00      0.33      0.50         3
#                                                 hematoma       1.00      0.78      0.88         9
#                                               hemiplegia       0.91      0.97      0.94       120
#                                          hemochromatosis       0.00      0.00      0.00         1
#                                         hemolytic anemia       1.00      1.00      1.00         1
#                                               hemophilia       0.86      1.00      0.92         6
#                                              hemorrhoids       0.95      0.84      0.89       202
#                                   hepatic encephalopathy       1.00      0.82      0.90        11
#                                 hepatitis due to a toxin       0.81      0.94      0.87        69
#                                           herniated disk       0.83      0.74      0.78       174
#                                               herpangina       0.90      0.93      0.92        91
#                                            hiatal hernia       0.96      0.94      0.95       185
#                                 hidradenitis suppurativa       1.00      0.83      0.91        35
#                                      high blood pressure       0.00      0.00      0.00         0
#                                     hirschsprung disease       1.00      0.50      0.67         6
#                                                hirsutism       1.00      1.00      1.00         6
#                                           histoplasmosis       1.00      1.00      1.00         1
#                                         hormone disorder       1.00      1.00      1.00         7
#                                                      hpv       1.00      1.00      1.00         2
#             human immunodeficiency virus infection (hiv)       0.00      0.00      0.00         0
#                                       huntington disease       0.00      0.00      0.00         1
#                                        hydatidiform mole       1.00      0.86      0.92        14
#                                hydrocele of the testicle       0.84      0.97      0.90        39
#                                            hydrocephalus       1.00      0.82      0.90        28
#                                           hydronephrosis       0.76      0.96      0.85        70
#                                            hypercalcemia       0.50      1.00      0.67         1
#                                     hypercholesterolemia       0.00      0.00      0.00         0
#                                   hyperemesis gravidarum       0.91      0.89      0.90       160
#                                   hypergammaglobulinemia       0.00      0.00      0.00         1
#                                            hyperhidrosis       1.00      1.00      1.00         5
#                                             hyperkalemia       0.90      0.95      0.92       123
#                                           hyperlipidemia       0.00      0.00      0.00         1
#                                            hypernatremia       1.00      0.75      0.86        12
#                                                hyperopia       0.96      0.96      0.96        25
#                          hyperosmotic hyperketotic state       0.00      0.00      0.00         1
#                                hypertension of pregnancy       0.77      1.00      0.87        10
#                               hypertensive heart disease       0.96      0.96      0.96       183
#           hypertrophic obstructive cardiomyopathy (hocm)       0.00      0.00      0.00         0
#                                             hypocalcemia       1.00      0.86      0.92         7
#                                             hypoglycemia       0.98      0.96      0.97       244
#                                              hypokalemia       0.94      0.91      0.92       101
#                                             hyponatremia       0.83      0.95      0.88        93
#                                              hypothermia       0.67      1.00      0.80         2
#                                           hypothyroidism       1.00      0.94      0.97        17
#                                              hypovolemia       0.82      0.90      0.86        83
#                       idiopathic absence of menstruation       0.89      0.98      0.94       104
#                        idiopathic excessive menstruation       0.87      0.78      0.82       173
#                       idiopathic infrequent menstruation       0.78      0.70      0.74        10
#                     idiopathic irregular menstrual cycle       0.76      0.92      0.83       192
#                         idiopathic nonmenstrual bleeding       1.00      0.75      0.86        20
#                          idiopathic painful menstruation       0.89      0.83      0.86       184
#                                                    ileus       0.95      0.82      0.88        92
#                                                 impetigo       0.95      0.92      0.94       149
#                                 impulse control disorder       0.67      0.64      0.65        74
#                                              indigestion       0.77      0.88      0.82       100
#                                         induced abortion       1.00      0.82      0.90        57
#                                  infection of open wound       0.83      0.83      0.83         6
#                               infectious gastroenteritis       0.89      0.48      0.62       254
#                                         ingrown toe nail       1.00      0.85      0.92       111
#                                          inguinal hernia       0.90      0.86      0.88        74
#                                      injury of the ankle       0.93      0.93      0.93        40
#                                 injury to internal organ       0.93      0.74      0.83        35
#                                    injury to the abdomen       1.00      0.77      0.87        13
#                                        injury to the arm       0.91      0.95      0.93       258
#                                       injury to the face       0.96      0.93      0.94        81
#                                     injury to the finger       0.00      0.00      0.00         2
#                                       injury to the hand       0.70      0.75      0.72        28
#                                        injury to the hip       1.00      0.60      0.75         5
#                                       injury to the knee       0.53      1.00      0.70         8
#                                        injury to the leg       0.89      0.96      0.92       234
#                                   injury to the shoulder       0.97      0.90      0.94       113
#                                injury to the spinal cord       1.00      0.86      0.92         7
#                                      injury to the trunk       1.00      0.96      0.98       182
#                                              insect bite       0.92      0.85      0.88       132
#                                         insulin overdose       0.67      1.00      0.80         2
#                                interstitial lung disease       0.83      0.86      0.84       120
#                              intertrigo (skin condition)       0.35      0.57      0.44        21
#                                        intestinal cancer       1.00      0.92      0.96        12
#                                       intestinal disease       0.74      0.83      0.78        71
#                                 intestinal malabsorption       1.00      0.85      0.92        39
#                                   intestinal obstruction       1.00      0.86      0.92        91
#                                 intracerebral hemorrhage       0.89      0.95      0.92       140
#                                     intracranial abscess       0.00      0.00      0.00         3
#                                  intracranial hemorrhage       0.95      0.80      0.87        65
#                                          intussusception       0.00      0.00      0.00         0
#                                            iridocyclitis       0.99      0.83      0.90       106
#                                   iron deficiency anemia       0.95      0.99      0.97       130
#                                 irritable bowel syndrome       0.99      0.92      0.95       103
#                                    ischemia of the bowel       0.75      0.55      0.63        55
#                                   ischemic heart disease       0.93      0.96      0.95       158
#                                 itching of unknown cause       0.95      0.98      0.96       109
#                                             jaw disorder       0.89      0.97      0.93        68
#                                           joint effusion       0.97      0.86      0.91        79
#                            juvenile rheumatoid arthritis       0.83      0.71      0.77         7
#                                           kaposi sarcoma       0.00      0.00      0.00         0
#                                            kidney cancer       0.78      1.00      0.88        14
#          kidney disease due to longstanding hypertension       1.00      1.00      1.00         4
#                                           kidney failure       0.87      0.89      0.88        54
#                                             kidney stone       0.64      0.63      0.64       191
#                           knee ligament or meniscus tear       0.88      1.00      0.93        21
#                                            labyrinthitis       0.99      0.95      0.97       156
#                                      lactose intolerance       1.00      0.92      0.96        26
#                                               laryngitis       0.98      0.91      0.94       149
#                     lateral epicondylitis (tennis elbow)       0.88      0.78      0.83        59
#                                                 leukemia       1.00      1.00      1.00         2
#                                       lewy body dementia       0.64      0.90      0.75        10
#                                                     lice       1.00      1.00      1.00        15
#                                            lichen planus       1.00      1.00      1.00         2
#                                           lichen simplex       1.00      0.90      0.95        10
#                                                   lipoma       0.98      0.96      0.97       136
#                                             liver cancer       0.83      1.00      0.91         5
#                                            liver disease       1.00      0.93      0.96       250
#                                                  lumbago       0.93      0.87      0.90        31
#                                              lung cancer       0.80      0.80      0.80         5
#                                           lung contusion       0.00      0.00      0.00         4
#                                             lyme disease       0.97      0.94      0.96        36
#                                            lymphadenitis       0.88      0.87      0.87        91
#                                             lymphangitis       0.00      0.00      0.00         1
#                                               lymphedema       0.81      0.99      0.89       102
#                                 lymphogranuloma venereum       1.00      1.00      1.00         2
#                                                 lymphoma       1.00      0.94      0.97        31
#                                     macular degeneration       0.98      0.62      0.76       184
#                                     magnesium deficiency       0.38      1.00      0.56        10
#                                                  malaria       1.00      1.00      1.00         1
#                                 male genitalia infection       0.97      0.97      0.97        32
#                                   malignant hypertension       0.88      0.92      0.90        38
#                                          marijuana abuse       0.80      0.67      0.73       242
#                                               mastectomy       1.00      0.80      0.89         5
#                                              mastoiditis       0.71      0.71      0.71        28
#                                      meckel diverticulum       1.00      1.00      1.00         1
#                                                 melanoma       0.96      0.93      0.95        59
#                                          meniere disease       0.91      0.94      0.93        53
#                                               meningioma       0.67      0.67      0.67         3
#                                               meningitis       0.74      0.87      0.80        52
#                                                menopause       1.00      0.93      0.97        15
#                                       metabolic disorder       1.00      1.00      1.00         8
#                                        metastatic cancer       1.00      0.83      0.91         6
#                                                 migraine       0.88      0.86      0.87        50
#                                          missed abortion       0.80      0.80      0.80        79
#                                     mitral valve disease       0.88      0.93      0.90        97
#                                            mittelschmerz       0.33      0.91      0.49        11
#                                    molluscum contagiosum       0.91      0.68      0.78        90
#                                             mononeuritis       0.89      0.90      0.90       153
#                                            mononucleosis       0.88      0.95      0.91        62
#                                         moyamoya disease       1.00      1.00      1.00         4
#                                                mucositis       0.94      0.85      0.89        54
#                                         multiple myeloma       0.92      1.00      0.96        12
#                                       multiple sclerosis       0.90      0.90      0.90       195
#                                                    mumps       0.89      0.89      0.89         9
#                                             muscle spasm       0.90      0.82      0.86       152
#                                       muscular dystrophy       1.00      1.00      1.00         7
#                                        myasthenia gravis       1.00      1.00      1.00        25
#                                 myelodysplastic syndrome       0.00      0.00      0.00         0
#                                              myocarditis       0.00      0.00      0.00         0
#                                                myoclonus       1.00      1.00      1.00         3
#                                                   myopia       1.00      0.72      0.84        79
#                                                 myositis       0.70      0.83      0.76        23
#                                               narcolepsy       0.78      0.97      0.86        33
#                                              nasal polyp       0.90      0.92      0.91        85
#                                    necrotizing fasciitis       0.00      0.00      0.00         1
#                                        neonatal jaundice       1.00      0.80      0.89         5
#                      nerve impingement near the shoulder       0.88      0.94      0.91        49
#                                                neuralgia       0.64      0.63      0.63       147
#                                        neurofibromatosis       1.00      0.83      0.91         6
#                                  neuropathy due to drugs       1.00      1.00      1.00         8
#                                                 neurosis       0.93      0.83      0.88       176
#                        nonalcoholic liver disease (nash)       0.83      1.00      0.91        10
#                            noninfectious gastroenteritis       0.62      0.87      0.73       251
#                            normal pressure hydrocephalus       1.00      1.00      1.00         3
#                                            nose disorder       0.93      0.81      0.86       221
#                                                  obesity       0.00      0.00      0.00         0
#                      obsessive compulsive disorder (ocd)       0.91      0.87      0.89        95
#                            obstructive sleep apnea (osa)       0.98      0.97      0.98       236
#                                               omphalitis       0.00      0.00      0.00         0
#                                            onychomycosis       0.77      0.88      0.83       104
#                                 open wound due to trauma       0.00      0.00      0.00         0
# ...
#                                                     scar       0.38      0.94      0.54        50
#                                            scarlet fever       0.93      0.76      0.84        17
#                                            schizophrenia       0.74      0.37      0.49       170
#                                                 sciatica       0.77      0.96      0.86       122
#                                                scleritis       0.75      0.75      0.75         4
#                                              scleroderma       0.90      0.84      0.87        67
#                                                scoliosis       0.91      1.00      0.95        29
#                                                   scurvy       0.00      0.00      0.00         1
#                           seasonal allergies (hay fever)       0.97      0.94      0.96       185
#                                           sebaceous cyst       0.89      0.96      0.92       172
#                                    seborrheic dermatitis       0.97      0.75      0.84       153
#                                     seborrheic keratosis       0.48      0.23      0.31       191
#                               sensorineural hearing loss       0.85      0.89      0.87       148
#                                                   sepsis       0.87      0.97      0.92       177
#                                         septic arthritis       0.52      1.00      0.68        16
#                                 shingles (herpes zoster)       1.00      0.99      0.99        71
#                                            sialoadenitis       0.91      0.97      0.94       107
#                                      sick sinus syndrome       0.37      0.52      0.43        33
#                                       sickle cell anemia       0.98      1.00      0.99        42
#                                       sickle cell crisis       0.99      0.88      0.93       172
#                                        sinus bradycardia       0.74      0.71      0.73       180
#                                         sjogren syndrome       0.80      1.00      0.89        20
#                                              skin cancer       0.88      0.57      0.69       124
#                                            skin disorder       0.40      0.59      0.48       137
#                               skin pigmentation disorder       0.40      0.48      0.43       172
#                                               skin polyp       0.42      0.39      0.40       189
#                             smoking or tobacco addiction       0.99      0.97      0.98       175
#                                            social phobia       0.49      0.86      0.62       105
#                                      soft tissue sarcoma       0.94      0.82      0.88        40
#                                    somatization disorder       0.88      0.91      0.89        23
#                                             spermatocele       1.00      0.75      0.86        16
#                                            spherocytosis       1.00      1.00      1.00         1
#                                             spina bifida       1.00      0.79      0.88        14
#                                          spinal stenosis       0.95      0.66      0.78       225
#                                   spinocerebellar ataxia       0.00      0.00      0.00         3
#                                              spondylitis       0.79      0.90      0.84        73
#                                        spondylolisthesis       0.76      0.78      0.77       148
#                                              spondylosis       0.77      0.76      0.77       251
#                                     spontaneous abortion       0.82      0.79      0.80       255
#                                           sporotrichosis       0.00      0.00      0.00         0
#                                         sprain or strain       0.89      0.93      0.91       233
#                                stenosis of the tear duct       0.92      0.86      0.89        14
#                                           stomach cancer       0.91      0.81      0.86        26
#                                             strep throat       0.97      0.88      0.92       261
#                                      stress incontinence       0.94      0.86      0.90        58
#                               stricture of the esophagus       1.00      0.77      0.87        22
#                                                   stroke       0.89      0.90      0.89       132
#                                                     stye       1.00      0.94      0.97       192
#                                     subacute thyroiditis       1.00      0.83      0.91         6
#                                  subarachnoid hemorrhage       0.94      1.00      0.97        34
#                               subconjunctival hemorrhage       0.93      0.85      0.89        47
#                                      subdural hemorrhage       1.00      0.91      0.95        23
#                        substance-related mental disorder       0.46      0.92      0.61        38
#       syndrome of inappropriate secretion of adh (siadh)       0.00      0.00      0.00         0
#                                                 syphilis       1.00      1.00      1.00         6
#                                            syringomyelia       1.00      0.50      0.67         2
#                       systemic lupus erythematosis (sle)       0.96      0.93      0.95        29
#                                        teething syndrome       0.93      0.91      0.92        78
#                       temporary or benign blood in urine       0.95      0.56      0.71       179
#                         temporomandibular joint disorder       0.85      0.96      0.90        69
#                                               tendinitis       0.91      0.89      0.90       128
#                                         tension headache       0.97      0.98      0.97        58
#                                        testicular cancer       1.00      1.00      1.00         1
#                                      testicular disorder       1.00      0.88      0.93         8
#                                       testicular torsion       0.94      0.84      0.89        19
#                                              thalassemia       0.00      0.00      0.00         0
#                                 thoracic aortic aneurysm       0.91      0.97      0.94        32
#                                 thoracic outlet syndrome       0.93      0.97      0.95        38
#                                     threatened pregnancy       0.72      0.77      0.74       183
#                                         thrombocytopenia       1.00      1.00      1.00        22
#                                         thrombophlebitis       0.99      0.98      0.98       100
#                                           thyroid cancer       0.00      0.00      0.00         4
#                                          thyroid disease       1.00      1.00      1.00         2
#                                           thyroid nodule       0.96      0.96      0.96        48
#                                  tic (movement) disorder       0.88      0.94      0.91        16
#                                          tietze syndrome       0.84      0.92      0.87        72
#                                tinnitus of unknown cause       0.71      0.77      0.74        48
#                                    tonsillar hypertrophy       0.83      0.97      0.89        61
#                                              tonsillitis       0.96      0.98      0.97        91
#                                            tooth abscess       0.79      0.97      0.87       119
#                                           tooth disorder       0.87      0.65      0.74       133
#                                              torticollis       0.98      0.98      0.98        49
#                                        tourette syndrome       1.00      0.75      0.86         4
#                                toxic multinodular goiter       1.00      0.73      0.85        15
#                                            toxoplasmosis       0.00      0.00      0.00         1
#                                               tracheitis       0.61      1.00      0.76        41
#                                transient ischemic attack       0.92      0.92      0.92       105
#                                               trichiasis       1.00      0.83      0.91         6
#                                              trichinosis       1.00      1.00      1.00         3
#                                    trichomonas infection       0.87      0.82      0.85        74
#                                  tricuspid valve disease       0.00      0.00      0.00         0
#                                     trigeminal neuralgia       0.88      0.90      0.89        41
#                         trigger finger (finger disorder)       0.75      0.92      0.83        13
#                                             tuberculosis       1.00      0.75      0.86         4
#                                       tuberous sclerosis       0.00      0.00      0.00         1
#                                          turner syndrome       0.00      0.00      0.00         0
#                                            typhoid fever       0.00      0.00      0.00         1
#                                       ulcerative colitis       0.97      0.80      0.88        75
#                                        urethral disorder       0.95      0.85      0.90        66
#                                       urethral stricture       1.00      0.77      0.87        71
#                                          urethral valves       1.00      1.00      1.00         5
#                                               urethritis       0.95      0.89      0.92        94
#                                        urge incontinence       0.94      0.94      0.94        90
#                                  urinary tract infection       0.71      0.81      0.76       178
#                                urinary tract obstruction       0.88      0.85      0.87       137
#                                            uterine atony       0.48      0.95      0.64        39
#                                           uterine cancer       1.00      1.00      1.00         1
#                                         uterine fibroids       0.93      0.72      0.81        88
#                                                  uveitis       1.00      1.00      1.00         3
#                                         vacterl syndrome       0.00      0.00      0.00         0
#                                             vaginal cyst       0.73      0.77      0.75       220
#                                  vaginal yeast infection       0.93      0.87      0.90       119
#                                               vaginismus       0.60      1.00      0.75        18
#                                                vaginitis       0.95      0.81      0.88       180
#                                             valley fever       0.00      0.00      0.00         0
#                              varicocele of the testicles       1.00      0.97      0.99       120
#                                           varicose veins       0.83      0.90      0.86        21
#                                               vasculitis       0.71      0.97      0.82        67
#                                     venous insufficiency       0.99      0.94      0.96        79
#                            vertebrobasilar insufficiency       0.67      0.67      0.67         3
#                                    vesicoureteral reflux       0.00      0.00      0.00         3
#                                           viral exanthem       0.95      0.78      0.86       114
#                                          viral hepatitis       1.00      0.78      0.88         9
#                                              viral warts       0.62      0.81      0.70        85
#                                     vitamin a deficiency       0.00      0.00      0.00         1
#                                   vitamin b12 deficiency       0.88      1.00      0.94        15
#                                     vitamin d deficiency       1.00      1.00      1.00         3
#                                    vitreous degeneration       0.00      0.00      0.00        79
#                                      vitreous hemorrhage       0.05      0.50      0.09         2
#                                         vocal cord polyp       0.95      0.86      0.90        22
#                                                 volvulus       1.00      0.67      0.80         3
#                                   von willebrand disease       0.00      0.00      0.00         2
#                                            vulvar cancer       0.00      0.00      0.00         0
#                                          vulvar disorder       0.97      0.82      0.89        44
#                                               vulvodynia       0.98      0.88      0.92       260
#                              wernicke korsakoff syndrome       0.00      0.00      0.00         2
#                                 white blood cell disease       0.97      0.85      0.90       111
#                                           whooping cough       0.31      0.45      0.37        11
#                                           wilson disease       1.00      1.00      1.00         1
#                                          yeast infection       0.71      0.99      0.83       106
#                                      zenker diverticulum       1.00      1.00      1.00         2
#
#                                                micro avg       0.85      0.85      0.85     49389
#                                                macro avg       0.76      0.75      0.75     49389
#                                             weighted avg       0.86      0.85      0.85     49389
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
torch.save(model, "/kaggle/working/xlm-roberta+ernie.pth")

# %%
torch.save(model, "/kaggle/working/xlm-roberta+ernie.h5")
