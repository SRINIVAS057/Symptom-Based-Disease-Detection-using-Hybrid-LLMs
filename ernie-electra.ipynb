# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import time
from transformers import AutoTokenizer, AutoModel
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import numpy as np

# %%
# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
# Load dataset
dataset_path = "/kaggle/input/diseases-and-symptoms-dataset/Final_Augmented_dataset_Diseases_and_Symptoms.csv"
df = pd.read_csv(dataset_path)

# %%
# Encode labels
label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['diseases'])

# %%
# Convert symptom columns to description
df['text_description'] = df.drop(columns=['diseases', 'label']).apply(lambda row: ' '.join(row.index[row == 1]), axis=1)

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(df['text_description'], df['label'], test_size=0.2, random_state=42)

# %%
# Load tokenizers
electra_tokenizer = AutoTokenizer.from_pretrained("google/electra-base-discriminator")
ernie_tokenizer = AutoTokenizer.from_pretrained("nghuyong/ernie-2.0-base-en")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/464 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
class SymptomHybridDataset(Dataset):
    def __init__(self, texts, labels, electra_tokenizer, ernie_tokenizer, max_length=128):
        self.texts = texts.tolist()
        self.labels = labels.tolist()
        self.electra_tokenizer = electra_tokenizer
        self.ernie_tokenizer = ernie_tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        electra_encoding = self.electra_tokenizer(
            self.texts[idx], truncation=True, padding="max_length",
            max_length=self.max_length, return_tensors="pt"
        )
        ernie_encoding = self.ernie_tokenizer(
            self.texts[idx], truncation=True, padding="max_length",
            max_length=self.max_length, return_tensors="pt"
        )
        return {
            "electra": {k: v.squeeze(0) for k, v in electra_encoding.items()},
            "ernie": {k: v.squeeze(0) for k, v in ernie_encoding.items()},
            "label": torch.tensor(self.labels[idx])
        }

# %%
train_dataset = SymptomHybridDataset(X_train, y_train, electra_tokenizer, ernie_tokenizer)
test_dataset = SymptomHybridDataset(X_test, y_test, electra_tokenizer, ernie_tokenizer)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
class ERNIE_ELECTRA_Classifier(nn.Module):
    def __init__(self, num_labels):
        super(ERNIE_ELECTRA_Classifier, self).__init__()
        self.num_labels = num_labels

        self.electra = AutoModel.from_pretrained("google/electra-base-discriminator")
        self.ernie = AutoModel.from_pretrained("nghuyong/ernie-2.0-en")

        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Linear(self.electra.config.hidden_size + self.ernie.config.hidden_size, num_labels)

    def forward(self, electra_input, ernie_input):
        electra_outputs = self.electra(**electra_input)
        ernie_outputs = self.ernie(**ernie_input)

        # Take [CLS] token representations
        electra_cls = electra_outputs.last_hidden_state[:, 0, :]
        ernie_cls = ernie_outputs.last_hidden_state[:, 0, :]

        combined = torch.cat((electra_cls, ernie_cls), dim=1)
        out = self.dropout(combined)
        return self.classifier(out)

# %%
# Initialize model
model = ERNIE_ELECTRA_Classifier(num_labels=len(label_encoder.classes_)).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=2e-5)
# Out:
# 2025-05-27 04:03:14.620504: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748318595.112445      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748318595.228980      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/464 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
# Training loop
num_epochs = 4
train_loss_values, test_loss_values = [], []
train_accuracies, test_accuracies = [], []
start_time = time.time()

for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0
    correct_train, total_train = 0, 0

    for batch in train_loader:
        optimizer.zero_grad()
        electra_inputs = {k: v.to(device) for k, v in batch["electra"].items()}
        ernie_inputs = {k: v.to(device) for k, v in batch["ernie"].items()}
        labels = batch["label"].to(device)

        outputs = model(electra_inputs, ernie_inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item()
        predictions = torch.argmax(outputs, dim=1)
        correct_train += (predictions == labels).sum().item()
        total_train += labels.size(0)

    avg_train_loss = total_train_loss / len(train_loader)
    train_accuracy = correct_train / total_train

    model.eval()
    total_test_loss = 0
    correct_test, total_test = 0, 0

    with torch.no_grad():
        for batch in test_loader:
            electra_inputs = {k: v.to(device) for k, v in batch["electra"].items()}
            ernie_inputs = {k: v.to(device) for k, v in batch["ernie"].items()}
            labels = batch["label"].to(device)

            outputs = model(electra_inputs, ernie_inputs)
            loss = criterion(outputs, labels)

            total_test_loss += loss.item()
            predictions = torch.argmax(outputs, dim=1)
            correct_test += (predictions == labels).sum().item()
            total_test += labels.size(0)

    avg_test_loss = total_test_loss / len(test_loader)
    test_accuracy = correct_test / total_test

    train_loss_values.append(avg_train_loss)
    test_loss_values.append(avg_test_loss)
    train_accuracies.append(train_accuracy)
    test_accuracies.append(test_accuracy)

    print(f"Epoch {epoch+1}: Train Loss = {avg_train_loss:.4f}, Train Acc = {train_accuracy:.4f}, Test Loss = {avg_test_loss:.4f}, Test Acc = {test_accuracy:.4f}")

end_time = time.time()
print(f"\nTotal Training Time: {end_time - start_time:.2f} seconds")
# Out:
# Epoch 1: Train Loss = 1.3079, Train Acc = 0.7284, Test Loss = 0.5217, Test Acc = 0.8353
# Epoch 2: Train Loss = 0.4984, Train Acc = 0.8413, Test Loss = 0.4535, Test Acc = 0.8449
# Epoch 3: Train Loss = 0.4367, Train Acc = 0.8505, Test Loss = 0.4305, Test Acc = 0.8475
# Epoch 4: Train Loss = 0.4065, Train Acc = 0.8559, Test Loss = 0.4277, Test Acc = 0.8475
#
# Total Training Time: 37089.29 seconds

# %%
# Plotting
plt.plot(range(1, num_epochs+1), train_loss_values, marker='o', label='Train Loss')
plt.plot(range(1, num_epochs+1), test_loss_values, marker='s', label='Test Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Curve")
plt.show()

plt.plot(range(1, num_epochs+1), train_accuracies, marker='o', label='Train Acc')
plt.plot(range(1, num_epochs+1), test_accuracies, marker='s', label='Test Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Curve")
plt.show()

# %%
# Final evaluation
y_true, y_pred = [], []
model.eval()
with torch.no_grad():
    for batch in test_loader:
        electra_inputs = {k: v.to(device) for k, v in batch["electra"].items()}
        ernie_inputs = {k: v.to(device) for k, v in batch["ernie"].items()}
        labels = batch["label"].to(device)

        outputs = model(electra_inputs, ernie_inputs)
        predictions = torch.argmax(outputs, dim=1)

        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predictions.cpu().numpy())

print("\nClassification Report:")
print(classification_report(y_true, y_pred, labels=np.arange(len(label_encoder.classes_)), target_names=label_encoder.classes_))
# Out:
# Classification Report:
#                                                           precision    recall  f1-score   support
#
#                                abdominal aortic aneurysm       1.00      1.00      1.00        20
#                                         abdominal hernia       0.90      0.99      0.94        81
#                                          abscess of nose       0.68      0.90      0.77        58
#                                      abscess of the lung       1.00      0.83      0.91         6
#                                   abscess of the pharynx       0.97      0.89      0.93        63
#                                     acanthosis nigricans       1.00      0.50      0.67         6
#                                                acariasis       0.83      1.00      0.91         5
#                                                achalasia       0.58      0.90      0.71        20
#                                                     acne       0.59      0.77      0.67       103
#                                        actinic keratosis       0.65      0.84      0.73       179
#                                      acute bronchiolitis       0.81      0.94      0.87       253
#                                         acute bronchitis       0.76      0.74      0.75       221
#                                       acute bronchospasm       0.73      0.73      0.73       187
#                    acute fatty liver of pregnancy (aflp)       0.50      1.00      0.67         3
#                                           acute glaucoma       0.58      0.23      0.33        31
#                                      acute kidney injury       0.89      0.98      0.93       209
#                                       acute otitis media       0.64      0.92      0.75       145
#                                       acute pancreatitis       0.92      0.88      0.90       246
#               acute respiratory distress syndrome (ards)       0.88      0.94      0.91        82
#                                          acute sinusitis       0.86      0.78      0.82       179
#                                    acute stress reaction       0.89      0.91      0.90       185
#                      adhesive capsulitis of the shoulder       1.00      0.82      0.90        17
#                                      adjustment reaction       0.76      0.78      0.77        89
#                                          adrenal adenoma       1.00      0.67      0.80         9
#                                           adrenal cancer       0.00      0.00      0.00         1
#                                            alcohol abuse       0.88      0.87      0.88        87
#                                     alcohol intoxication       0.97      0.90      0.93        62
#                                       alcohol withdrawal       0.92      0.97      0.94       148
#                                  alcoholic liver disease       0.95      0.93      0.94        44
#                                                  allergy       0.86      0.96      0.91       182
#                                       allergy to animals       1.00      1.00      1.00         8
#                                                 alopecia       0.72      0.89      0.79        70
#                                        alzheimer disease       0.97      0.94      0.96        70
#                                                amblyopia       0.93      1.00      0.96        13
#                                              amyloidosis       1.00      1.00      1.00         1
#                      amyotrophic lateral sclerosis (als)       1.00      0.78      0.88         9
#                                             anal fissure       0.92      0.94      0.93        36
#                                             anal fistula       1.00      1.00      1.00         1
#                                                   anemia       0.98      0.93      0.95        57
#                     anemia due to chronic kidney disease       1.00      0.83      0.91         6
#                                 anemia due to malignancy       1.00      1.00      1.00         1
#                                anemia of chronic disease       1.00      0.71      0.83         7
#                                                   angina       0.97      0.92      0.94       179
#                                   ankylosing spondylitis       0.98      0.71      0.83       126
#                                                  anxiety       0.99      0.92      0.95       236
#                                     aortic valve disease       0.94      0.89      0.91        84
#                                                  aphakia       0.00      0.00      0.00         1
#                                           aphthous ulcer       1.00      0.84      0.91        44
#                                          aplastic anemia       1.00      1.00      1.00        16
#                                             appendicitis       0.96      0.74      0.84       183
#                                               arrhythmia       0.83      0.75      0.79        52
#                                     arthritis of the hip       0.85      0.98      0.91       228
#                                    ascending cholangitis       0.67      0.80      0.73        10
#                                        asperger syndrome       0.87      0.76      0.81        80
#                                            aspergillosis       1.00      1.00      1.00         3
#                                                   asthma       0.70      0.84      0.76       189
#                                              astigmatism       0.64      0.64      0.64        55
#                                              atelectasis       0.61      0.64      0.62        22
#                                           athlete's foot       0.72      0.63      0.67        73
#                                           atonic bladder       0.79      0.73      0.76        15
#                                      atrial fibrillation       1.00      0.21      0.35        19
#                                           atrial flutter       0.69      0.92      0.79        51
#                                  atrophic skin condition       0.91      0.79      0.84        85
#                                       atrophic vaginitis       0.80      0.86      0.83        66
#                         atrophy of the corpus cavernosum       1.00      0.60      0.75         5
#          attention deficit hyperactivity disorder (adhd)       0.81      0.87      0.84        99
#                                                   autism       0.97      0.86      0.91        73
#                        autonomic nervous system disorder       1.00      0.90      0.95        21
#                                       avascular necrosis       0.00      0.00      0.00         8
#                                                balanitis       1.00      0.97      0.99       106
#                                               bell palsy       0.99      0.96      0.97       140
#                                       benign kidney cyst       0.91      0.90      0.91        48
#             benign paroxysmal positional vertical (bppv)       0.95      0.99      0.97        82
#                       benign prostatic hyperplasia (bph)       0.89      0.95      0.92       244
#                    benign vaginal discharge (leukorrhea)       0.85      0.92      0.88       131
#                                         bipolar disorder       0.71      0.67      0.69       132
#                                             birth trauma       1.00      1.00      1.00         1
#                                           bladder cancer       0.96      0.96      0.96        27
#                                         bladder disorder       0.41      0.89      0.56        83
#                                      bladder obstruction       0.97      0.89      0.93        66
#                                              blepharitis       0.67      0.77      0.72       180
#                                            blepharospasm       1.00      1.00      1.00         1
#                                              bone cancer       1.00      0.78      0.88        23
#                                            bone disorder       1.00      0.98      0.99        51
#                              bone spur of the calcaneous       0.71      1.00      0.83         5
#                                        brachial neuritis       0.88      0.93      0.90       177
#                                             brain cancer       0.83      0.89      0.86        45
#                                            breast cancer       0.00      0.00      0.00         0
#                                              breast cyst       0.75      0.60      0.67         5
#                              breast infection (mastitis)       0.97      1.00      0.98        96
#                                             broken tooth       0.94      1.00      0.97        33
#                                                   bunion       1.00      0.78      0.88         9
#                                                     burn       0.82      0.90      0.86        10
#                                                 bursitis       0.98      0.99      0.98       252
#                                                   callus       0.68      0.85      0.75        97
#                                carbon monoxide poisoning       0.94      0.89      0.92        19
#                                       carcinoid syndrome       0.00      0.00      0.00         2
#                                           cardiac arrest       0.94      0.89      0.91        72
#                                           cardiomyopathy       0.86      0.73      0.79        52
#                                   carpal tunnel syndrome       0.98      0.90      0.94       167
#                                      cat scratch disease       0.00      0.00      0.00         2
#                                                 cataract       0.67      0.56      0.61       115
#                                           celiac disease       0.78      0.97      0.86        29
#                           cellulitis or abscess of mouth       1.00      0.97      0.98        33
#                                  central atherosclerosis       1.00      0.50      0.67         4
#                 central retinal artery or vein occlusion       1.00      0.71      0.83        14
#                                           cerebral edema       0.80      0.95      0.87        21
#                                           cerebral palsy       0.90      0.90      0.90        21
#                                          cervical cancer       1.00      0.95      0.98        21
#                                        cervical disorder       0.58      0.78      0.67         9
#                                               cervicitis       0.75      0.79      0.77        76
#                                                chalazion       1.00      0.82      0.90       112
#                                               chickenpox       1.00      0.83      0.90        23
#                                                chlamydia       0.58      0.70      0.64        30
#                                            cholecystitis       0.97      0.77      0.86       275
#                                      choledocholithiasis       0.94      0.92      0.93        85
#                                            cholesteatoma       0.88      1.00      0.93         7
#                            chondromalacia of the patella       1.00      0.67      0.80         6
#                                          chorioretinitis       1.00      0.80      0.89        15
#                                        chronic back pain       0.97      0.92      0.95       187
#                                     chronic constipation       0.92      0.84      0.88       178
#                                         chronic glaucoma       0.70      0.72      0.71       146
# chronic inflammatory demyelinating polyneuropathy (cidp)       1.00      0.50      0.67         2
#                                   chronic kidney disease       1.00      0.50      0.67         2
#                                        chronic knee pain       0.48      0.91      0.63        33
#             chronic obstructive pulmonary disease (copd)       0.73      0.38      0.50       168
#                                     chronic otitis media       0.94      0.82      0.87       136
#                                    chronic pain disorder       0.93      0.78      0.85       127
#                                     chronic pancreatitis       0.98      0.98      0.98        55
#                                  chronic rheumatic fever       0.79      0.89      0.84        35
#                                        chronic sinusitis       0.70      0.96      0.81       137
#                                            chronic ulcer       0.00      0.00      0.00         0
#                                                cirrhosis       0.95      1.00      0.97        56
#                          coagulation (bleeding) disorder       1.00      1.00      1.00        16
#                                                cold sore       0.82      1.00      0.90        36
#                                            colonic polyp       0.92      0.90      0.91        60
#                                        colorectal cancer       0.33      0.50      0.40         2
#                                              common cold       0.70      0.95      0.80       148
#                           complex regional pain syndrome       1.00      0.83      0.91       244
#                                               concussion       1.00      0.95      0.97       239
#                                         conduct disorder       0.91      0.87      0.89       134
#                                  conductive hearing loss       0.99      0.87      0.93       103
#                                  congenital heart defect       1.00      1.00      1.00         8
#                         congenital malformation syndrome       1.00      1.00      1.00         2
#                                           conjunctivitis       0.96      0.86      0.91       197
#                            conjunctivitis due to allergy       0.97      0.84      0.90       242
#                           conjunctivitis due to bacteria       0.63      0.97      0.77        32
#                              conjunctivitis due to virus       0.74      0.86      0.80       131
#                               connective tissue disorder       0.00      0.00      0.00         0
#                                       contact dermatitis       0.81      0.74      0.77       192
#                                      conversion disorder       1.00      1.00      1.00         2
#                                         cornea infection       0.87      0.76      0.81       186
#                                         corneal abrasion       0.41      0.83      0.55       104
#                                         corneal disorder       0.58      0.57      0.58       122
#                                 coronary atherosclerosis       0.89      0.77      0.83        22
#                                      cranial nerve palsy       0.96      0.96      0.96        67
#                                            crohn disease       0.85      0.84      0.85        75
#                                                    croup       0.71      0.88      0.79       202
#                                          crushing injury       0.77      0.91      0.83        11
#                                           cryptococcosis       1.00      1.00      1.00         5
#                                           cryptorchidism       0.00      0.00      0.00         0
#                                         cushing syndrome       1.00      1.00      1.00         2
#                                       cyst of the eyelid       1.00      1.00      1.00         4
#                                          cystic fibrosis       1.00      1.00      1.00         4
#                                            cysticercosis       1.00      0.78      0.88         9
#                                                 cystitis       0.98      0.65      0.78       266
#                                      de quervain disease       1.00      0.83      0.91        12
#                                          decubitus ulcer       0.00      0.00      0.00         0
#                               deep vein thrombosis (dvt)       0.97      0.95      0.96        40
#                                degenerative disc disease       0.55      0.88      0.68       182
#                                                 delirium       0.98      0.82      0.89       136
#                                                 dementia       0.87      0.87      0.87        69
#                                             dengue fever       0.00      0.00      0.00         1
#                                            dental caries       0.91      0.91      0.91       236
#                                               depression       1.00      0.60      0.75       198
#                           dermatitis due to sun exposure       0.67      0.77      0.72        88
#                                 developmental disability       0.91      0.94      0.92       188
#                                    deviated nasal septum       0.90      0.95      0.93       126
#                                                 diabetes       0.00      0.00      0.00         1
#                                       diabetes insipidus       0.00      0.00      0.00         0
#                                    diabetic ketoacidosis       0.91      0.90      0.91       119
#                                  diabetic kidney disease       0.00      0.00      0.00         0
#                           diabetic peripheral neuropathy       0.91      0.99      0.95        83
#                                     diabetic retinopathy       0.59      0.64      0.61        88
#                                              diaper rash       0.94      1.00      0.97       200
#                                 dislocation of the ankle       1.00      1.00      1.00         4
#                                 dislocation of the elbow       1.00      0.79      0.88        19
#                                dislocation of the finger       1.00      1.00      1.00         3
#                                  dislocation of the foot       1.00      1.00      1.00         3
#                                   dislocation of the hip       0.00      0.00      0.00         4
#                                  dislocation of the knee       0.00      0.00      0.00         0
#                               dislocation of the patella       0.00      0.00      0.00         0
#                              dislocation of the shoulder       1.00      0.67      0.80         9
#                              dislocation of the vertebra       1.00      0.85      0.92        13
#                                 dislocation of the wrist       0.73      1.00      0.84         8
#                                    dissociative disorder       1.00      0.79      0.88        24
#                                           diverticulitis       0.88      0.84      0.86       246
#                                           diverticulosis       0.88      0.84      0.86       143
#                                            down syndrome       0.94      0.79      0.86        39
#                                               drug abuse       0.89      0.85      0.87       124
#                                drug abuse (barbiturates)       0.65      0.73      0.69        15
#                                     drug abuse (cocaine)       0.93      0.46      0.61        57
#                             drug abuse (methamphetamine)       0.71      0.97      0.82        74
#                                     drug abuse (opioids)       0.74      0.78      0.76       114
#                         drug poisoning due to medication       1.00      0.93      0.96        43
#                                            drug reaction       0.97      0.97      0.97       176
#                                          drug withdrawal       0.92      0.89      0.90        53
#                                 dry eye of unknown cause       0.96      0.40      0.57       174
#                                         dumping syndrome       0.00      0.00      0.00         0
#                                              dyshidrosis       0.94      0.94      0.94        17
#                                       dysthymic disorder       0.67      0.98      0.79        97
#                                          ear drum damage       0.89      0.88      0.88       192
#                                        ear wax impaction       0.81      0.82      0.81       133
#                                          eating disorder       0.87      1.00      0.93        83
#                                        ectopic pregnancy       0.74      0.85      0.79        65
#                                                ectropion       0.00      0.00      0.00         8
#                                                   eczema       0.90      0.71      0.80       227
#                                          edward syndrome       1.00      1.00      1.00         1
#                                                emphysema       1.00      0.75      0.86         8
#                                                  empyema       0.00      0.00      0.00         2
#                                             encephalitis       0.83      1.00      0.91        20
#                                             endocarditis       0.55      0.32      0.40        19
#                                       endometrial cancer       0.92      1.00      0.96        22
#                                  endometrial hyperplasia       1.00      1.00      1.00         8
#                                            endometriosis       0.98      0.92      0.95        64
#                                          endophthalmitis       0.91      1.00      0.95        10
#                  envenomation from spider or animal bite       0.99      0.96      0.98       106
#                                               ependymoma       1.00      1.00      1.00         4
#                                             epididymitis       0.97      0.96      0.96        95
#                                      epidural hemorrhage       0.00      0.00      0.00         0
#                                                 epilepsy       1.00      0.92      0.96        13
#                                     erectile dysfunction       0.89      0.84      0.87       126
#                                      erythema multiforme       0.90      1.00      0.95         9
#                                        esophageal cancer       0.85      0.89      0.87        19
#                                       esophageal varices       0.00      0.00      0.00         3
#                                              esophagitis       0.90      0.91      0.91       263
#                                         essential tremor       0.97      0.97      0.97        35
#               eustachian tube dysfunction (ear disorder)       0.95      0.95      0.95       169
#                           extrapyramidal effect of drugs       0.92      1.00      0.96        12
#                                   eye alignment disorder       0.99      0.95      0.97        88
#                                      factitious disorder       0.50      1.00      0.67         1
#                               female genitalia infection       1.00      0.97      0.99        36
#                      female infertility of unknown cause       1.00      1.00      1.00         6
#                                   fetal alcohol syndrome       0.00      0.00      0.00         0
#                                             fibroadenoma       1.00      0.88      0.93        24
#                               fibrocystic breast disease       1.00      1.00      1.00         2
#                                             fibromyalgia       0.74      0.74      0.74       127
#                                                flat feet       1.00      0.86      0.92         7
#                                                 floaters       0.00      0.00      0.00         6
#                                                      flu       0.96      0.82      0.88       116
#                                           fluid overload       1.00      0.83      0.90        69
#                                        folate deficiency       0.67      0.57      0.62         7
#                                             food allergy       0.81      0.96      0.88        95
#                                  foreign body in the ear       1.00      0.33      0.50         6
#                                  foreign body in the eye       0.54      0.82      0.65        57
#               foreign body in the gastrointestinal tract       1.00      1.00      1.00        22
#                                 foreign body in the nose       0.00      0.00      0.00         0
#                               foreign body in the throat       0.92      1.00      0.96        35
#                               foreign body in the vagina       1.00      0.75      0.86         4
#                                    fracture of the ankle       1.00      0.45      0.62        11
#                                      fracture of the arm       0.81      0.89      0.85        81
#                             fracture of the facial bones       0.99      0.91      0.95        96
#                                   fracture of the finger       0.00      0.00      0.00         1
#                                     fracture of the foot       0.50      0.33      0.40         3
#                                     fracture of the hand       0.75      0.55      0.63        22
#                                      fracture of the jaw       1.00      0.83      0.91        12
#                                      fracture of the leg       0.91      0.93      0.92       148
#                                     fracture of the neck       0.45      0.90      0.60        10
#                                  fracture of the patella       0.95      0.90      0.92        20
#                                   fracture of the pelvis       1.00      0.79      0.88        43
#                                      fracture of the rib       0.99      0.94      0.96       172
#                                 fracture of the shoulder       1.00      1.00      1.00        35
#                                    fracture of the skull       0.78      0.78      0.78         9
#                                 fracture of the vertebra       1.00      0.90      0.95        50
#                                         friedrich ataxia       0.00      0.00      0.00         0
#                                                frostbite       1.00      0.75      0.86         4
#                             fungal infection of the hair       0.71      0.76      0.73       279
#                             fungal infection of the skin       0.69      0.60      0.64       126
#                                   g6pd enzyme deficiency       0.50      1.00      0.67         1
#                            galactorrhea of unknown cause       0.67      0.67      0.67         3
#                                                gallstone       0.66      0.86      0.75       176
#                                            ganglion cyst       1.00      0.97      0.98       158
#                                             gas gangrene       0.00      0.00      0.00         0
#                                                gastritis       0.80      0.86      0.83       141
#                                     gastroduodenal ulcer       0.92      0.81      0.86       139
#                   gastroesophageal reflux disease (gerd)       0.93      0.88      0.91        76
#                              gastrointestinal hemorrhage       0.89      0.97      0.92       239
#                                            gastroparesis       0.78      0.68      0.72        37
#                                           genital herpes       0.98      0.91      0.94        45
#                                     gestational diabetes       0.50      0.33      0.40         6
#                                                 glaucoma       0.60      0.69      0.64        96
#                                glucocorticoid deficiency       1.00      1.00      1.00         2
#                                                   goiter       1.00      1.00      1.00        17
#                                                gonorrhea       1.00      1.00      1.00        17
#                                                     gout       0.90      0.94      0.92       252
#                                      granuloma inguinale       1.00      0.50      0.67         2
#                                           graves disease       0.85      0.94      0.89        49
#                                  guillain barre syndrome       1.00      1.00      1.00        17
#                                              gum disease       0.80      0.79      0.79       197
#                                             gynecomastia       0.94      0.94      0.94        18
#                                               hammer toe       0.00      0.00      0.00         0
#                                    hashimoto thyroiditis       0.00      0.00      0.00         1
#                                     head and neck cancer       0.87      0.99      0.93        75
#                                              head injury       0.81      0.94      0.87        36
#                           headache after lumbar puncture       0.97      0.97      0.97        30
#                                             heart attack       0.98      0.93      0.95       167
#                                              heart block       0.76      0.88      0.82       110
#                                          heart contusion       0.00      0.00      0.00         3
#                                            heart failure       0.88      0.93      0.90       176
#                                          heat exhaustion       0.77      0.91      0.83        47
#                                              heat stroke       0.00      0.00      0.00         0
#                                               hemangioma       0.87      0.75      0.80       130
#                                             hemarthrosis       1.00      0.33      0.50         3
#                                                 hematoma       0.88      0.78      0.82         9
#                                               hemiplegia       0.93      0.96      0.95       120
#                                          hemochromatosis       0.00      0.00      0.00         1
#                                         hemolytic anemia       1.00      1.00      1.00         1
#                                               hemophilia       0.83      0.83      0.83         6
#                                              hemorrhoids       0.96      0.88      0.92       202
#                                   hepatic encephalopathy       0.92      1.00      0.96        11
#                                 hepatitis due to a toxin       0.89      0.97      0.93        69
#                                           herniated disk       0.88      0.71      0.79       174
#                                               herpangina       0.98      0.91      0.94        91
#                                            hiatal hernia       0.89      0.95      0.92       185
#                                 hidradenitis suppurativa       1.00      0.89      0.94        35
#                                      high blood pressure       0.00      0.00      0.00         0
#                                     hirschsprung disease       1.00      0.50      0.67         6
#                                                hirsutism       1.00      1.00      1.00         6
#                                           histoplasmosis       1.00      1.00      1.00         1
#                                         hormone disorder       1.00      1.00      1.00         7
#                                                      hpv       0.50      1.00      0.67         2
#             human immunodeficiency virus infection (hiv)       0.00      0.00      0.00         0
#                                       huntington disease       0.00      0.00      0.00         1
#                                        hydatidiform mole       0.92      0.86      0.89        14
#                                hydrocele of the testicle       0.78      1.00      0.88        39
#                                            hydrocephalus       1.00      0.75      0.86        28
#                                           hydronephrosis       0.78      0.89      0.83        70
#                                            hypercalcemia       0.00      0.00      0.00         1
#                                     hypercholesterolemia       0.00      0.00      0.00         0
#                                   hyperemesis gravidarum       0.91      0.89      0.90       160
#                                   hypergammaglobulinemia       0.00      0.00      0.00         1
#                                            hyperhidrosis       1.00      1.00      1.00         5
#                                             hyperkalemia       0.91      0.96      0.94       123
#                                           hyperlipidemia       0.00      0.00      0.00         1
#                                            hypernatremia       0.79      0.92      0.85        12
#                                                hyperopia       1.00      0.88      0.94        25
#                          hyperosmotic hyperketotic state       0.00      0.00      0.00         1
#                                hypertension of pregnancy       0.83      1.00      0.91        10
#                               hypertensive heart disease       0.99      0.93      0.96       183
#           hypertrophic obstructive cardiomyopathy (hocm)       0.00      0.00      0.00         0
#                                             hypocalcemia       1.00      0.86      0.92         7
#                                             hypoglycemia       0.99      0.94      0.97       244
#                                              hypokalemia       0.90      0.88      0.89       101
#                                             hyponatremia       0.96      0.87      0.92        93
#                                              hypothermia       0.67      1.00      0.80         2
#                                           hypothyroidism       1.00      0.94      0.97        17
#                                              hypovolemia       0.95      0.92      0.93        83
#                       idiopathic absence of menstruation       0.99      0.88      0.93       104
#                        idiopathic excessive menstruation       0.89      0.79      0.83       173
#                       idiopathic infrequent menstruation       0.44      0.80      0.57        10
#                     idiopathic irregular menstrual cycle       0.81      0.91      0.86       192
#                         idiopathic nonmenstrual bleeding       1.00      0.75      0.86        20
#                          idiopathic painful menstruation       0.92      0.77      0.83       184
#                                                    ileus       0.90      0.87      0.88        92
#                                                 impetigo       0.95      0.87      0.91       149
#                                 impulse control disorder       0.61      0.81      0.69        74
#                                              indigestion       0.87      0.84      0.85       100
#                                         induced abortion       0.85      0.89      0.87        57
#                                  infection of open wound       0.71      0.83      0.77         6
#                               infectious gastroenteritis       0.90      0.47      0.62       254
#                                         ingrown toe nail       0.96      0.90      0.93       111
#                                          inguinal hernia       1.00      0.78      0.88        74
#                                      injury of the ankle       0.94      0.85      0.89        40
#                                 injury to internal organ       1.00      0.74      0.85        35
#                                    injury to the abdomen       0.86      0.92      0.89        13
#                                        injury to the arm       0.95      0.94      0.94       258
#                                       injury to the face       0.96      0.93      0.94        81
#                                     injury to the finger       1.00      0.50      0.67         2
#                                       injury to the hand       0.89      0.61      0.72        28
#                                        injury to the hip       1.00      0.60      0.75         5
#                                       injury to the knee       0.60      0.75      0.67         8
#                                        injury to the leg       0.95      0.94      0.95       234
#                                   injury to the shoulder       0.90      0.91      0.91       113
#                                injury to the spinal cord       1.00      0.86      0.92         7
#                                      injury to the trunk       0.99      0.97      0.98       182
#                                              insect bite       0.92      0.92      0.92       132
#                                         insulin overdose       0.67      1.00      0.80         2
#                                interstitial lung disease       0.90      0.81      0.85       120
#                              intertrigo (skin condition)       0.53      0.38      0.44        21
#                                        intestinal cancer       1.00      0.83      0.91        12
#                                       intestinal disease       0.65      0.92      0.76        71
#                                 intestinal malabsorption       1.00      0.87      0.93        39
#                                   intestinal obstruction       1.00      0.87      0.93        91
#                                 intracerebral hemorrhage       0.97      0.87      0.92       140
#                                     intracranial abscess       0.75      1.00      0.86         3
#                                  intracranial hemorrhage       0.90      0.82      0.85        65
#                                          intussusception       0.00      0.00      0.00         0
#                                            iridocyclitis       0.91      0.91      0.91       106
#                                   iron deficiency anemia       0.98      0.98      0.98       130
#                                 irritable bowel syndrome       0.92      0.92      0.92       103
#                                    ischemia of the bowel       0.58      0.96      0.72        55
#                                   ischemic heart disease       0.96      0.96      0.96       158
#                                 itching of unknown cause       0.97      0.94      0.95       109
#                                             jaw disorder       0.98      0.93      0.95        68
#                                           joint effusion       0.93      1.00      0.96        79
#                            juvenile rheumatoid arthritis       1.00      0.57      0.73         7
#                                           kaposi sarcoma       0.00      0.00      0.00         0
#                                            kidney cancer       1.00      0.93      0.96        14
#          kidney disease due to longstanding hypertension       1.00      1.00      1.00         4
#                                           kidney failure       1.00      0.89      0.94        54
#                                             kidney stone       0.57      0.73      0.64       191
#                           knee ligament or meniscus tear       1.00      0.95      0.98        21
#                                            labyrinthitis       0.89      0.98      0.93       156
#                                      lactose intolerance       1.00      0.88      0.94        26
#                                               laryngitis       0.93      0.90      0.91       149
#                     lateral epicondylitis (tennis elbow)       0.85      0.78      0.81        59
#                                                 leukemia       1.00      1.00      1.00         2
#                                       lewy body dementia       0.56      1.00      0.71        10
#                                                     lice       1.00      1.00      1.00        15
#                                            lichen planus       1.00      1.00      1.00         2
#                                           lichen simplex       1.00      0.90      0.95        10
#                                                   lipoma       0.96      0.95      0.96       136
#                                             liver cancer       0.62      1.00      0.77         5
#                                            liver disease       0.87      0.98      0.92       250
#                                                  lumbago       0.90      0.84      0.87        31
#                                              lung cancer       0.75      0.60      0.67         5
#                                           lung contusion       1.00      1.00      1.00         4
#                                             lyme disease       1.00      0.94      0.97        36
#                                            lymphadenitis       0.82      0.91      0.86        91
#                                             lymphangitis       0.00      0.00      0.00         1
#                                               lymphedema       0.97      0.92      0.94       102
#                                 lymphogranuloma venereum       1.00      1.00      1.00         2
#                                                 lymphoma       1.00      0.94      0.97        31
#                                     macular degeneration       0.73      0.68      0.71       184
#                                     magnesium deficiency       0.34      1.00      0.51        10
#                                                  malaria       1.00      1.00      1.00         1
#                                 male genitalia infection       1.00      0.97      0.98        32
#                                   malignant hypertension       0.77      0.95      0.85        38
#                                          marijuana abuse       0.86      0.66      0.75       242
#                                               mastectomy       1.00      0.80      0.89         5
#                                              mastoiditis       0.77      0.61      0.68        28
#                                      meckel diverticulum       1.00      1.00      1.00         1
#                                                 melanoma       0.95      0.93      0.94        59
#                                          meniere disease       0.94      0.87      0.90        53
#                                               meningioma       0.67      0.67      0.67         3
#                                               meningitis       0.73      0.85      0.79        52
#                                                menopause       1.00      1.00      1.00        15
#                                       metabolic disorder       1.00      0.88      0.93         8
#                                        metastatic cancer       1.00      1.00      1.00         6
#                                                 migraine       0.80      0.90      0.85        50
#                                          missed abortion       1.00      0.77      0.87        79
#                                     mitral valve disease       0.61      0.98      0.75        97
#                                            mittelschmerz       0.77      0.91      0.83        11
#                                    molluscum contagiosum       0.86      0.68      0.76        90
#                                             mononeuritis       0.90      0.90      0.90       153
#                                            mononucleosis       0.93      0.89      0.91        62
#                                         moyamoya disease       0.80      1.00      0.89         4
#                                                mucositis       0.88      0.93      0.90        54
#                                         multiple myeloma       1.00      1.00      1.00        12
#                                       multiple sclerosis       0.90      0.93      0.91       195
#                                                    mumps       0.89      0.89      0.89         9
#                                             muscle spasm       0.75      0.92      0.83       152
#                                       muscular dystrophy       1.00      1.00      1.00         7
#                                        myasthenia gravis       1.00      0.96      0.98        25
#                                 myelodysplastic syndrome       0.00      0.00      0.00         0
#                                              myocarditis       0.00      0.00      0.00         0
#                                                myoclonus       1.00      1.00      1.00         3
#                                                   myopia       0.93      0.82      0.87        79
#                                                 myositis       0.77      0.87      0.82        23
#                                               narcolepsy       0.97      1.00      0.99        33
#                                              nasal polyp       0.99      0.82      0.90        85
#                                    necrotizing fasciitis       0.00      0.00      0.00         1
#                                        neonatal jaundice       1.00      0.80      0.89         5
#                      nerve impingement near the shoulder       0.84      0.96      0.90        49
#                                                neuralgia       0.49      0.71      0.58       147
#                                        neurofibromatosis       1.00      0.83      0.91         6
#                                  neuropathy due to drugs       1.00      1.00      1.00         8
#                                                 neurosis       0.95      0.84      0.89       176
#                        nonalcoholic liver disease (nash)       1.00      1.00      1.00        10
#                            noninfectious gastroenteritis       0.61      0.90      0.73       251
#                            normal pressure hydrocephalus       1.00      1.00      1.00         3
#                                            nose disorder       0.91      0.79      0.85       221
#                                                  obesity       0.00      0.00      0.00         0
#                      obsessive compulsive disorder (ocd)       0.91      0.86      0.89        95
#                            obstructive sleep apnea (osa)       0.97      0.97      0.97       236
#                                               omphalitis       0.00      0.00      0.00         0
#                                            onychomycosis       0.75      0.91      0.83       104
#                                 open wound due to trauma       0.00      0.00      0.00         0
# ...
#                                                     scar       0.47      0.80      0.59        50
#                                            scarlet fever       1.00      0.88      0.94        17
#                                            schizophrenia       0.71      0.51      0.59       170
#                                                 sciatica       0.81      0.95      0.87       122
#                                                scleritis       1.00      0.75      0.86         4
#                                              scleroderma       0.84      0.85      0.84        67
#                                                scoliosis       0.83      1.00      0.91        29
#                                                   scurvy       1.00      1.00      1.00         1
#                           seasonal allergies (hay fever)       0.97      0.91      0.94       185
#                                           sebaceous cyst       0.92      0.91      0.92       172
#                                    seborrheic dermatitis       0.94      0.78      0.85       153
#                                     seborrheic keratosis       0.33      0.59      0.42       191
#                               sensorineural hearing loss       0.87      0.89      0.88       148
#                                                   sepsis       0.88      0.92      0.90       177
#                                         septic arthritis       0.62      1.00      0.76        16
#                                 shingles (herpes zoster)       1.00      0.99      0.99        71
#                                            sialoadenitis       1.00      0.94      0.97       107
#                                      sick sinus syndrome       0.56      0.70      0.62        33
#                                       sickle cell anemia       1.00      1.00      1.00        42
#                                       sickle cell crisis       0.99      0.88      0.93       172
#                                        sinus bradycardia       0.92      0.66      0.77       180
#                                         sjogren syndrome       0.80      1.00      0.89        20
#                                              skin cancer       0.62      0.68      0.65       124
#                                            skin disorder       0.37      0.18      0.24       137
#                               skin pigmentation disorder       0.35      0.59      0.44       172
#                                               skin polyp       0.45      0.21      0.28       189
#                             smoking or tobacco addiction       0.97      0.99      0.98       175
#                                            social phobia       0.61      0.80      0.69       105
#                                      soft tissue sarcoma       0.94      0.82      0.88        40
#                                    somatization disorder       0.81      0.96      0.88        23
#                                             spermatocele       0.84      1.00      0.91        16
#                                            spherocytosis       1.00      1.00      1.00         1
#                                             spina bifida       1.00      0.79      0.88        14
#                                          spinal stenosis       0.77      0.69      0.73       225
#                                   spinocerebellar ataxia       0.00      0.00      0.00         3
#                                              spondylitis       0.92      0.95      0.93        73
#                                        spondylolisthesis       0.96      0.68      0.80       148
#                                              spondylosis       0.85      0.73      0.78       251
#                                     spontaneous abortion       0.76      0.90      0.82       255
#                                           sporotrichosis       0.00      0.00      0.00         0
#                                         sprain or strain       0.93      0.91      0.92       233
#                                stenosis of the tear duct       0.75      0.86      0.80        14
#                                           stomach cancer       0.85      0.88      0.87        26
#                                             strep throat       0.97      0.88      0.92       261
#                                      stress incontinence       1.00      0.83      0.91        58
#                               stricture of the esophagus       1.00      0.82      0.90        22
#                                                   stroke       0.83      0.95      0.88       132
#                                                     stye       0.97      0.96      0.97       192
#                                     subacute thyroiditis       1.00      1.00      1.00         6
#                                  subarachnoid hemorrhage       1.00      0.94      0.97        34
#                               subconjunctival hemorrhage       0.95      0.81      0.87        47
#                                      subdural hemorrhage       0.81      0.96      0.88        23
#                        substance-related mental disorder       0.50      0.61      0.55        38
#       syndrome of inappropriate secretion of adh (siadh)       0.00      0.00      0.00         0
#                                                 syphilis       1.00      1.00      1.00         6
#                                            syringomyelia       0.50      0.50      0.50         2
#                       systemic lupus erythematosis (sle)       1.00      0.90      0.95        29
#                                        teething syndrome       0.91      0.91      0.91        78
#                       temporary or benign blood in urine       0.75      0.75      0.75       179
#                         temporomandibular joint disorder       0.82      0.96      0.89        69
#                                               tendinitis       0.95      0.84      0.89       128
#                                         tension headache       1.00      0.90      0.95        58
#                                        testicular cancer       1.00      1.00      1.00         1
#                                      testicular disorder       1.00      0.88      0.93         8
#                                       testicular torsion       1.00      0.84      0.91        19
#                                              thalassemia       0.00      0.00      0.00         0
#                                 thoracic aortic aneurysm       1.00      0.78      0.88        32
#                                 thoracic outlet syndrome       0.90      1.00      0.95        38
#                                     threatened pregnancy       0.96      0.61      0.75       183
#                                         thrombocytopenia       0.96      1.00      0.98        22
#                                         thrombophlebitis       0.96      1.00      0.98       100
#                                           thyroid cancer       1.00      0.75      0.86         4
#                                          thyroid disease       1.00      1.00      1.00         2
#                                           thyroid nodule       0.98      0.96      0.97        48
#                                  tic (movement) disorder       0.88      0.94      0.91        16
#                                          tietze syndrome       0.81      0.92      0.86        72
#                                tinnitus of unknown cause       0.69      0.92      0.79        48
#                                    tonsillar hypertrophy       0.95      0.90      0.92        61
#                                              tonsillitis       0.98      0.96      0.97        91
#                                            tooth abscess       0.88      0.82      0.85       119
#                                           tooth disorder       0.74      0.80      0.77       133
#                                              torticollis       0.96      0.96      0.96        49
#                                        tourette syndrome       1.00      0.75      0.86         4
#                                toxic multinodular goiter       1.00      0.67      0.80        15
#                                            toxoplasmosis       0.00      0.00      0.00         1
#                                               tracheitis       0.77      0.59      0.67        41
#                                transient ischemic attack       0.84      0.97      0.90       105
#                                               trichiasis       1.00      0.83      0.91         6
#                                              trichinosis       1.00      1.00      1.00         3
#                                    trichomonas infection       0.92      0.82      0.87        74
#                                  tricuspid valve disease       0.00      0.00      0.00         0
#                                     trigeminal neuralgia       0.97      0.95      0.96        41
#                         trigger finger (finger disorder)       0.67      0.92      0.77        13
#                                             tuberculosis       1.00      0.75      0.86         4
#                                       tuberous sclerosis       0.00      0.00      0.00         1
#                                          turner syndrome       0.00      0.00      0.00         0
#                                            typhoid fever       0.00      0.00      0.00         1
#                                       ulcerative colitis       0.77      0.92      0.84        75
#                                        urethral disorder       0.88      0.92      0.90        66
#                                       urethral stricture       0.98      0.79      0.88        71
#                                          urethral valves       1.00      1.00      1.00         5
#                                               urethritis       0.98      0.89      0.93        94
#                                        urge incontinence       0.94      0.92      0.93        90
#                                  urinary tract infection       0.61      0.88      0.72       178
#                                urinary tract obstruction       0.87      0.83      0.85       137
#                                            uterine atony       0.67      0.92      0.77        39
#                                           uterine cancer       1.00      1.00      1.00         1
#                                         uterine fibroids       0.75      0.93      0.83        88
#                                                  uveitis       1.00      1.00      1.00         3
#                                         vacterl syndrome       0.00      0.00      0.00         0
#                                             vaginal cyst       0.78      0.71      0.74       220
#                                  vaginal yeast infection       0.86      0.84      0.85       119
#                                               vaginismus       0.76      0.89      0.82        18
#                                                vaginitis       0.95      0.79      0.86       180
#                                             valley fever       0.00      0.00      0.00         0
#                              varicocele of the testicles       1.00      0.97      0.99       120
#                                           varicose veins       0.95      0.86      0.90        21
#                                               vasculitis       0.98      0.93      0.95        67
#                                     venous insufficiency       0.94      0.96      0.95        79
#                            vertebrobasilar insufficiency       0.50      1.00      0.67         3
#                                    vesicoureteral reflux       0.00      0.00      0.00         3
#                                           viral exanthem       0.87      0.85      0.86       114
#                                          viral hepatitis       0.88      0.78      0.82         9
#                                              viral warts       0.88      0.78      0.82        85
#                                     vitamin a deficiency       1.00      1.00      1.00         1
#                                   vitamin b12 deficiency       1.00      1.00      1.00        15
#                                     vitamin d deficiency       1.00      1.00      1.00         3
#                                    vitreous degeneration       0.48      0.82      0.60        79
#                                      vitreous hemorrhage       0.00      0.00      0.00         2
#                                         vocal cord polyp       1.00      0.82      0.90        22
#                                                 volvulus       1.00      0.33      0.50         3
#                                   von willebrand disease       0.00      0.00      0.00         2
#                                            vulvar cancer       0.00      0.00      0.00         0
#                                          vulvar disorder       0.88      0.98      0.92        44
#                                               vulvodynia       0.90      0.91      0.90       260
#                              wernicke korsakoff syndrome       0.00      0.00      0.00         2
#                                 white blood cell disease       0.92      0.91      0.91       111
#                                           whooping cough       0.50      0.36      0.42        11
#                                           wilson disease       1.00      1.00      1.00         1
#                                          yeast infection       0.82      1.00      0.90       106
#                                      zenker diverticulum       0.67      1.00      0.80         2
#
#                                                micro avg       0.85      0.85      0.85     49389
#                                                macro avg       0.77      0.76      0.76     49389
#                                             weighted avg       0.86      0.85      0.85     49389
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
